# %% [markdown]
# # Project-257_Resume Classification

# %% [markdown]
# Business objective-
#
#
# The document classification solution should significantly reduce the manual human effort in the HRM. It should achieve a higher level of accuracy and automation with minimal human intervention

# %% [markdown]
# > **Import Libraries**

# %%
pip install textract
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: textract in /usr/local/lib/python3.10/dist-packages (1.6.5)
# Requirement already satisfied: argcomplete~=1.10.0 in /usr/local/lib/python3.10/dist-packages (from textract) (1.10.3)
# Requirement already satisfied: beautifulsoup4~=4.8.0 in /usr/local/lib/python3.10/dist-packages (from textract) (4.8.2)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from textract) (3.0.4)
# Requirement already satisfied: docx2txt~=0.8 in /usr/local/lib/python3.10/dist-packages (from textract) (0.8)
# Requirement already satisfied: extract-msg<=0.29.* in /usr/local/lib/python3.10/dist-packages (from textract) (0.28.7)
# Requirement already satisfied: pdfminer.six==20191110 in /usr/local/lib/python3.10/dist-packages (from textract) (20191110)
# Requirement already satisfied: python-pptx~=0.6.18 in /usr/local/lib/python3.10/dist-packages (from textract) (0.6.21)
# Requirement already satisfied: six~=1.12.0 in /usr/local/lib/python3.10/dist-packages (from textract) (1.12.0)
# Requirement already satisfied: SpeechRecognition~=3.8.1 in /usr/local/lib/python3.10/dist-packages (from textract) (3.8.1)
# Requirement already satisfied: xlrd~=1.2.0 in /usr/local/lib/python3.10/dist-packages (from textract) (1.2.0)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20191110->textract) (3.18.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20191110->textract) (2.4.0)
# Requirement already satisfied: soupsieve>=1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4~=4.8.0->textract) (2.4.1)
# Requirement already satisfied: imapclient==2.1.0 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (2.1.0)
# Requirement already satisfied: olefile>=0.46 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (0.46)
# Requirement already satisfied: tzlocal>=2.1 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (5.0.1)
# Requirement already satisfied: compressed-rtf>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (1.0.6)
# Requirement already satisfied: ebcdic>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (1.1.1)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract) (4.9.2)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract) (8.4.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract) (3.1.2)

# %%
import pandas as pd
import os
import textract

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# # IMPORT DATA

# %%
os.listdir("/content/drive/MyDrive/P-257")
# Out:
# ['Internship',
#  'Peoplesoft resumes',
#  'React JS developer',
#  'SQL Developer Lightning insight',
#  'workday resumes']

# %% [markdown]
#  **For Internship**

# %%
file_path1 = []
category1 = []
directory1 = '/content/drive/MyDrive/P-257/Internship'

for i in os.listdir(directory1):
    if i.endswith('.docx'):
        file = os.path.join(directory1, i)
        extracted_text = textract.process(file).decode('utf-8')
        file_path1.append(extracted_text)
        category1.append('Internship')

# %%
data1 = pd.DataFrame(data = file_path1 , columns = ['Raw_Details'])
data1['Category1'] = category1
data1
# Out:
#                                          Raw_Details   Category1
# 0  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...  Internship
# 1  Name: Ravali P \n\n\n\n                       ...  Internship

# %% [markdown]
# **For PeopleSoft Resumes**

# %%
file_path2 = []
category2 = []
directory2 = '/content/drive/MyDrive/P-257/Peoplesoft resumes'

for i in os.listdir(directory2):
    if i.endswith('.docx'):
        file = os.path.join(directory2, i)
        extracted_text = textract.process(file).decode('utf-8')
        file_path2.append(extracted_text)
        category2.append('Peoplesoft resumes')

# %%
data2 = pd.DataFrame(data = file_path2 , columns = ['Raw_Details'])
data2['Category2'] = category2
data2
# Out:
#                                          Raw_Details           Category2
# 0  PeopleSoft Administration\n\n \n\nVivekanand S...  Peoplesoft resumes
# 1  Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...  Peoplesoft resumes
# 2  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...  Peoplesoft resumes
# 3  C O N T A C T :\n\n\n\nAddress: Manyata Tech P...  Peoplesoft resumes
# 4  PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...  Peoplesoft resumes
# 5  Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...  Peoplesoft resumes
# 6  Hari Narayana \t\t              \n\n\t\n\n\n\n...  Peoplesoft resumes
# 7  Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...  Peoplesoft resumes
# 8  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...  Peoplesoft resumes
# 9  Classification: Internal\n\nClassification: In...  Peoplesoft resumes

# %% [markdown]
# **For React JS Developer**

# %%
file_path3 = []
category3 = []
directory3 = '/content/drive/MyDrive/P-257/React JS developer'

for i in os.listdir(directory3):
    if i.endswith('.docx'):
        file = os.path.join(directory3, i)
        extracted_text = textract.process(file).decode('utf-8')
        file_path3.append(extracted_text)
        category3.append('React JS developer')

# %%
data3 = pd.DataFrame(data = file_path3 , columns = ['Raw_Details'])
data3['Category3'] = category3
data3
# Out:
#                                           Raw_Details           Category3
# 0   MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...  React JS developer
# 1   Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...  React JS developer
# 2   Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...  React JS developer
# 3   MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...  React JS developer
# 4   Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...  React JS developer
# 5   PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...  React JS developer
# 6   Venkatalakshmi Pedireddy\n\nSoftware Developer...  React JS developer
# 7   Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...  React JS developer
# 8   KAMALAKAR REDDY. A \n\nLinked In: https://www....  React JS developer
# 9   SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...  React JS developer
# 10  Naveen Sadhu\n\n\n\n\n\nTitle: software develo...  React JS developer
# 11  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...  React JS developer
# 12  Ui-Developer/ React JS Developer \n\nNAME: KRI...  React JS developer
# 13  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...  React JS developer
# 14  Ui-Developer/ React JS Developer \n\nNAME: KRI...  React JS developer
# 15  Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...  React JS developer
# 16  SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...  React JS developer
# 17  HARIPRIYA BATTINA \n\nExperience as UI Develop...  React JS developer

# %% [markdown]
# **For SQL Developer Lightning Insight**

# %%
file_path4 = []
category4 = []
directory4 = '/content/drive/MyDrive/P-257/SQL Developer Lightning insight'

for i in os.listdir(directory4):
  if i.endswith('.docx'):
    file = os.path.join(directory4,i)
    extracted_text =textract.process(file).decode('utf-8')
    file_path4.append(extracted_text)
    category4.append('SQL Developer Lightning insight')

# %%
data4 = pd.DataFrame(data = file_path4 , columns = ['Raw_Details'])
data4['Category4'] = category4
data4
# Out:
#                                           Raw_Details  \
# 0   KAMBALLA PRADEEP                              ...
# 1   ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...
# 2   SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...
# 3   Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...
# 4   SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...
# 5   RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...
# 6   SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...
# 7   resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...
# 8   Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...
# 9   BUDDHA VAMSI                                  ...
# 10  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...
#
#                           Category4
# 0   SQL Developer Lightning insight
# 1   SQL Developer Lightning insight
# 2   SQL Developer Lightning insight
# 3   SQL Developer Lightning insight
# 4   SQL Developer Lightning insight
# 5   SQL Developer Lightning insight
# 6   SQL Developer Lightning insight
# 7   SQL Developer Lightning insight
# 8   SQL Developer Lightning insight
# 9   SQL Developer Lightning insight
# 10  SQL Developer Lightning insight

# %% [markdown]
# **For Workday Resumes**

# %%
file_path5 = []
category5 = []
directory5 = '/content/drive/MyDrive/P-257/workday resumes'

for i in os.listdir(directory5):
  if i.endswith('.docx'):
    file = os.path.join(directory5,i)
    extracted_text =textract.process(file).decode('utf-8')
    file_path5.append(extracted_text)
    category5.append('workday resumes')

# %%
data5 = pd.DataFrame(data = file_path5 , columns = ['Raw_Details'])
data5['Category5'] = category5
data5
# Out:
#                                           Raw_Details        Category5
# 0   G Himaja\n\n                                  ...  workday resumes
# 1   WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...  workday resumes
# 2   Vinay kumar .v\nWorkday Functional Consultant\...  workday resumes
# 3   Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...  workday resumes
# 4   VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...  workday resumes
# 5   Srikanth (WORKDAY hCM Consultant)\t           ...  workday resumes
# 6   Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...  workday resumes
# 7   Workday HCM  Techno functional Consultant     ...  workday resumes
# 8   Mooraboyina Guravaiah\n\nWorkday Integration S...  workday resumes
# 9   JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...  workday resumes
# 10  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...  workday resumes

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
resume_data = data1.append([data2, data3, data4, data5,], ignore_index = True)
resume_data
# Out:
# <ipython-input-142-c9780094aa9e>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resume_data = data1.append([data2, data3, data4, data5,], ignore_index = True)
#                                           Raw_Details   Category1  \
# 0   SUSOVAN  BAG   \n\nSeeking  a  challenging  po...  Internship
# 1   Name: Ravali P \n\n\n\n                       ...  Internship
# 2   PeopleSoft Administration\n\n \n\nVivekanand S...         NaN
# 3   Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...         NaN
# 4   SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...         NaN
# 5   C O N T A C T :\n\n\n\nAddress: Manyata Tech P...         NaN
# 6   PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...         NaN
# 7   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...         NaN
# 8   Hari Narayana \t\t              \n\n\t\n\n\n\n...         NaN
# 9   Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...         NaN
# 10  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...         NaN
# 11  Classification: Internal\n\nClassification: In...         NaN
# 12  MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...         NaN
# 13  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...         NaN
# 14  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...         NaN
# 15  MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...         NaN
# 16  Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...         NaN
# 17  PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...         NaN
# 18  Venkatalakshmi Pedireddy\n\nSoftware Developer...         NaN
# 19  Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...         NaN
# 20  KAMALAKAR REDDY. A \n\nLinked In: https://www....         NaN
# 21  SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...         NaN
# 22  Naveen Sadhu\n\n\n\n\n\nTitle: software develo...         NaN
# 23  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...         NaN
# 24  Ui-Developer/ React JS Developer \n\nNAME: KRI...         NaN
# 25  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...         NaN
# 26  Ui-Developer/ React JS Developer \n\nNAME: KRI...         NaN
# 27  Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...         NaN
# 28  SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...         NaN
# 29  HARIPRIYA BATTINA \n\nExperience as UI Develop...         NaN
# 30  KAMBALLA PRADEEP                              ...         NaN
# 31  ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...         NaN
# 32  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...         NaN
# 33  Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...         NaN
# 34  SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...         NaN
# 35  RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...         NaN
# 36  SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...         NaN
# 37  resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...         NaN
# 38  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...         NaN
# 39  BUDDHA VAMSI                                  ...         NaN
# 40  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...         NaN
# 41  G Himaja\n\n                                  ...         NaN
# 42  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...         NaN
# 43  Vinay kumar .v\nWorkday Functional Consultant\...         NaN
# 44  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...         NaN
# 45  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...         NaN
# 46  Srikanth (WORKDAY hCM Consultant)\t           ...         NaN
# 47  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...         NaN
# 48  Workday HCM  Techno functional Consultant     ...         NaN
# 49  Mooraboyina Guravaiah\n\nWorkday Integration S...         NaN
# 50  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...         NaN
# 51  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...         NaN
#
#              Category2           Category3                        Category4  \
# 0                  NaN                 NaN                              NaN
# 1                  NaN                 NaN                              NaN
# 2   Peoplesoft resumes                 NaN                              NaN
# 3   Peoplesoft resumes                 NaN                              NaN
# 4   Peoplesoft resumes                 NaN                              NaN
# 5   Peoplesoft resumes                 NaN                              NaN
# 6   Peoplesoft resumes                 NaN                              NaN
# 7   Peoplesoft resumes                 NaN                              NaN
# 8   Peoplesoft resumes                 NaN                              NaN
# 9   Peoplesoft resumes                 NaN                              NaN
# 10  Peoplesoft resumes                 NaN                              NaN
# 11  Peoplesoft resumes                 NaN                              NaN
# 12                 NaN  React JS developer                              NaN
# 13                 NaN  React JS developer                              NaN
# 14                 NaN  React JS developer                              NaN
# 15                 NaN  React JS developer                              NaN
# 16                 NaN  React JS developer                              NaN
# 17                 NaN  React JS developer                              NaN
# 18                 NaN  React JS developer                              NaN
# 19                 NaN  React JS developer                              NaN
# 20                 NaN  React JS developer                              NaN
# 21                 NaN  React JS developer                              NaN
# 22                 NaN  React JS developer                              NaN
# 23                 NaN  React JS developer                              NaN
# 24                 NaN  React JS developer                              NaN
# 25                 NaN  React JS developer                              NaN
# 26                 NaN  React JS developer                              NaN
# 27                 NaN  React JS developer                              NaN
# 28                 NaN  React JS developer                              NaN
# 29                 NaN  React JS developer                              NaN
# 30                 NaN                 NaN  SQL Developer Lightning insight
# 31                 NaN                 NaN  SQL Developer Lightning insight
# 32                 NaN                 NaN  SQL Developer Lightning insight
# 33                 NaN                 NaN  SQL Developer Lightning insight
# 34                 NaN                 NaN  SQL Developer Lightning insight
# 35                 NaN                 NaN  SQL Developer Lightning insight
# 36                 NaN                 NaN  SQL Developer Lightning insight
# 37                 NaN                 NaN  SQL Developer Lightning insight
# 38                 NaN                 NaN  SQL Developer Lightning insight
# 39                 NaN                 NaN  SQL Developer Lightning insight
# 40                 NaN                 NaN  SQL Developer Lightning insight
# 41                 NaN                 NaN                              NaN
# 42                 NaN                 NaN                              NaN
# 43                 NaN                 NaN                              NaN
# 44                 NaN                 NaN                              NaN
# 45                 NaN                 NaN                              NaN
# 46                 NaN                 NaN                              NaN
# 47                 NaN                 NaN                              NaN
# 48                 NaN                 NaN                              NaN
# 49                 NaN                 NaN                              NaN
# 50                 NaN                 NaN                              NaN
# 51                 NaN                 NaN                              NaN
#
#           Category5
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# 30              NaN
# 31              NaN
# 32              NaN
# 33              NaN
# 34              NaN
# 35              NaN
# 36              NaN
# 37              NaN
# 38              NaN
# 39              NaN
# 40              NaN
# 41  workday resumes
# 42  workday resumes
# 43  workday resumes
# 44  workday resumes
# 45  workday resumes
# 46  workday resumes
# 47  workday resumes
# 48  workday resumes
# 49  workday resumes
# 50  workday resumes
# 51  workday resumes

# %%
resume_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Raw_Details  52 non-null     object
#  1   Category1    2 non-null      object
#  2   Category2    10 non-null     object
#  3   Category3    18 non-null     object
#  4   Category4    11 non-null     object
#  5   Category5    11 non-null     object
# dtypes: object(6)
# memory usage: 2.6+ KB

# %%
resume_data.head()
# Out:
#                                          Raw_Details   Category1  \
# 0  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...  Internship
# 1  Name: Ravali P \n\n\n\n                       ...  Internship
# 2  PeopleSoft Administration\n\n \n\nVivekanand S...         NaN
# 3  Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...         NaN
# 4  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...         NaN
#
#             Category2 Category3 Category4 Category5
# 0                 NaN       NaN       NaN       NaN
# 1                 NaN       NaN       NaN       NaN
# 2  Peoplesoft resumes       NaN       NaN       NaN
# 3  Peoplesoft resumes       NaN       NaN       NaN
# 4  Peoplesoft resumes       NaN       NaN       NaN

# %%
resume_data.tail()
# Out:
#                                           Raw_Details Category1 Category2  \
# 47  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...       NaN       NaN
# 48  Workday HCM  Techno functional Consultant     ...       NaN       NaN
# 49  Mooraboyina Guravaiah\n\nWorkday Integration S...       NaN       NaN
# 50  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...       NaN       NaN
# 51  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...       NaN       NaN
#
#    Category3 Category4        Category5
# 47       NaN       NaN  workday resumes
# 48       NaN       NaN  workday resumes
# 49       NaN       NaN  workday resumes
# 50       NaN       NaN  workday resumes
# 51       NaN       NaN  workday resumes

# %%
resume_data.shape
# Out:
# (52, 6)

# %%
resume_data['Category'] = category1 + category2 + category3 + category4 + category5
resume_data
# Out:
#                                           Raw_Details   Category1  \
# 0   SUSOVAN  BAG   \n\nSeeking  a  challenging  po...  Internship
# 1   Name: Ravali P \n\n\n\n                       ...  Internship
# 2   PeopleSoft Administration\n\n \n\nVivekanand S...         NaN
# 3   Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...         NaN
# 4   SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...         NaN
# 5   C O N T A C T :\n\n\n\nAddress: Manyata Tech P...         NaN
# 6   PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...         NaN
# 7   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...         NaN
# 8   Hari Narayana \t\t              \n\n\t\n\n\n\n...         NaN
# 9   Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...         NaN
# 10  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...         NaN
# 11  Classification: Internal\n\nClassification: In...         NaN
# 12  MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...         NaN
# 13  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...         NaN
# 14  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...         NaN
# 15  MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...         NaN
# 16  Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...         NaN
# 17  PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...         NaN
# 18  Venkatalakshmi Pedireddy\n\nSoftware Developer...         NaN
# 19  Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...         NaN
# 20  KAMALAKAR REDDY. A \n\nLinked In: https://www....         NaN
# 21  SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...         NaN
# 22  Naveen Sadhu\n\n\n\n\n\nTitle: software develo...         NaN
# 23  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...         NaN
# 24  Ui-Developer/ React JS Developer \n\nNAME: KRI...         NaN
# 25  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...         NaN
# 26  Ui-Developer/ React JS Developer \n\nNAME: KRI...         NaN
# 27  Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...         NaN
# 28  SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...         NaN
# 29  HARIPRIYA BATTINA \n\nExperience as UI Develop...         NaN
# 30  KAMBALLA PRADEEP                              ...         NaN
# 31  ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...         NaN
# 32  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...         NaN
# 33  Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...         NaN
# 34  SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...         NaN
# 35  RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...         NaN
# 36  SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...         NaN
# 37  resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...         NaN
# 38  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...         NaN
# 39  BUDDHA VAMSI                                  ...         NaN
# 40  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...         NaN
# 41  G Himaja\n\n                                  ...         NaN
# 42  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...         NaN
# 43  Vinay kumar .v\nWorkday Functional Consultant\...         NaN
# 44  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...         NaN
# 45  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...         NaN
# 46  Srikanth (WORKDAY hCM Consultant)\t           ...         NaN
# 47  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...         NaN
# 48  Workday HCM  Techno functional Consultant     ...         NaN
# 49  Mooraboyina Guravaiah\n\nWorkday Integration S...         NaN
# 50  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...         NaN
# 51  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...         NaN
#
#              Category2           Category3                        Category4  \
# 0                  NaN                 NaN                              NaN
# 1                  NaN                 NaN                              NaN
# 2   Peoplesoft resumes                 NaN                              NaN
# 3   Peoplesoft resumes                 NaN                              NaN
# 4   Peoplesoft resumes                 NaN                              NaN
# 5   Peoplesoft resumes                 NaN                              NaN
# 6   Peoplesoft resumes                 NaN                              NaN
# 7   Peoplesoft resumes                 NaN                              NaN
# 8   Peoplesoft resumes                 NaN                              NaN
# 9   Peoplesoft resumes                 NaN                              NaN
# 10  Peoplesoft resumes                 NaN                              NaN
# 11  Peoplesoft resumes                 NaN                              NaN
# 12                 NaN  React JS developer                              NaN
# 13                 NaN  React JS developer                              NaN
# 14                 NaN  React JS developer                              NaN
# 15                 NaN  React JS developer                              NaN
# 16                 NaN  React JS developer                              NaN
# 17                 NaN  React JS developer                              NaN
# 18                 NaN  React JS developer                              NaN
# 19                 NaN  React JS developer                              NaN
# 20                 NaN  React JS developer                              NaN
# 21                 NaN  React JS developer                              NaN
# 22                 NaN  React JS developer                              NaN
# 23                 NaN  React JS developer                              NaN
# 24                 NaN  React JS developer                              NaN
# 25                 NaN  React JS developer                              NaN
# 26                 NaN  React JS developer                              NaN
# 27                 NaN  React JS developer                              NaN
# 28                 NaN  React JS developer                              NaN
# 29                 NaN  React JS developer                              NaN
# 30                 NaN                 NaN  SQL Developer Lightning insight
# 31                 NaN                 NaN  SQL Developer Lightning insight
# 32                 NaN                 NaN  SQL Developer Lightning insight
# 33                 NaN                 NaN  SQL Developer Lightning insight
# 34                 NaN                 NaN  SQL Developer Lightning insight
# 35                 NaN                 NaN  SQL Developer Lightning insight
# 36                 NaN                 NaN  SQL Developer Lightning insight
# 37                 NaN                 NaN  SQL Developer Lightning insight
# 38                 NaN                 NaN  SQL Developer Lightning insight
# 39                 NaN                 NaN  SQL Developer Lightning insight
# 40                 NaN                 NaN  SQL Developer Lightning insight
# 41                 NaN                 NaN                              NaN
# 42                 NaN                 NaN                              NaN
# 43                 NaN                 NaN                              NaN
# 44                 NaN                 NaN                              NaN
# 45                 NaN                 NaN                              NaN
# 46                 NaN                 NaN                              NaN
# 47                 NaN                 NaN                              NaN
# 48                 NaN                 NaN                              NaN
# 49                 NaN                 NaN                              NaN
# 50                 NaN                 NaN                              NaN
# 51                 NaN                 NaN                              NaN
#
#           Category5                         Category
# 0               NaN                       Internship
# 1               NaN                       Internship
# 2               NaN               Peoplesoft resumes
# 3               NaN               Peoplesoft resumes
# 4               NaN               Peoplesoft resumes
# 5               NaN               Peoplesoft resumes
# 6               NaN               Peoplesoft resumes
# 7               NaN               Peoplesoft resumes
# 8               NaN               Peoplesoft resumes
# 9               NaN               Peoplesoft resumes
# 10              NaN               Peoplesoft resumes
# 11              NaN               Peoplesoft resumes
# 12              NaN               React JS developer
# 13              NaN               React JS developer
# 14              NaN               React JS developer
# 15              NaN               React JS developer
# 16              NaN               React JS developer
# 17              NaN               React JS developer
# 18              NaN               React JS developer
# 19              NaN               React JS developer
# 20              NaN               React JS developer
# 21              NaN               React JS developer
# 22              NaN               React JS developer
# 23              NaN               React JS developer
# 24              NaN               React JS developer
# 25              NaN               React JS developer
# 26              NaN               React JS developer
# 27              NaN               React JS developer
# 28              NaN               React JS developer
# 29              NaN               React JS developer
# 30              NaN  SQL Developer Lightning insight
# 31              NaN  SQL Developer Lightning insight
# 32              NaN  SQL Developer Lightning insight
# 33              NaN  SQL Developer Lightning insight
# 34              NaN  SQL Developer Lightning insight
# 35              NaN  SQL Developer Lightning insight
# 36              NaN  SQL Developer Lightning insight
# 37              NaN  SQL Developer Lightning insight
# 38              NaN  SQL Developer Lightning insight
# 39              NaN  SQL Developer Lightning insight
# 40              NaN  SQL Developer Lightning insight
# 41  workday resumes                  workday resumes
# 42  workday resumes                  workday resumes
# 43  workday resumes                  workday resumes
# 44  workday resumes                  workday resumes
# 45  workday resumes                  workday resumes
# 46  workday resumes                  workday resumes
# 47  workday resumes                  workday resumes
# 48  workday resumes                  workday resumes
# 49  workday resumes                  workday resumes
# 50  workday resumes                  workday resumes
# 51  workday resumes                  workday resumes

# %%
resume_data.drop(['Category1' , 'Category2' , 'Category3' , 'Category4' , 'Category5' ], axis = 1,inplace = True)
resume_data = resume_data[["Category" , "Raw_Details"]]

# %%
resume_data
# Out:
#                            Category  \
# 0                        Internship
# 1                        Internship
# 2                Peoplesoft resumes
# 3                Peoplesoft resumes
# 4                Peoplesoft resumes
# 5                Peoplesoft resumes
# 6                Peoplesoft resumes
# 7                Peoplesoft resumes
# 8                Peoplesoft resumes
# 9                Peoplesoft resumes
# 10               Peoplesoft resumes
# 11               Peoplesoft resumes
# 12               React JS developer
# 13               React JS developer
# 14               React JS developer
# 15               React JS developer
# 16               React JS developer
# 17               React JS developer
# 18               React JS developer
# 19               React JS developer
# 20               React JS developer
# 21               React JS developer
# 22               React JS developer
# 23               React JS developer
# 24               React JS developer
# 25               React JS developer
# 26               React JS developer
# 27               React JS developer
# 28               React JS developer
# 29               React JS developer
# 30  SQL Developer Lightning insight
# 31  SQL Developer Lightning insight
# 32  SQL Developer Lightning insight
# 33  SQL Developer Lightning insight
# 34  SQL Developer Lightning insight
# 35  SQL Developer Lightning insight
# 36  SQL Developer Lightning insight
# 37  SQL Developer Lightning insight
# 38  SQL Developer Lightning insight
# 39  SQL Developer Lightning insight
# 40  SQL Developer Lightning insight
# 41                  workday resumes
# 42                  workday resumes
# 43                  workday resumes
# 44                  workday resumes
# 45                  workday resumes
# 46                  workday resumes
# 47                  workday resumes
# 48                  workday resumes
# 49                  workday resumes
# 50                  workday resumes
# 51                  workday resumes
#
#                                           Raw_Details
# 0   SUSOVAN  BAG   \n\nSeeking  a  challenging  po...
# 1   Name: Ravali P \n\n\n\n                       ...
# 2   PeopleSoft Administration\n\n \n\nVivekanand S...
# 3   Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...
# 4   SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...
# 5   C O N T A C T :\n\n\n\nAddress: Manyata Tech P...
# 6   PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...
# 7   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# 8   Hari Narayana \t\t              \n\n\t\n\n\n\n...
# 9   Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...
# 10  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...
# 11  Classification: Internal\n\nClassification: In...
# 12  MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...
# 13  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...
# 14  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...
# 15  MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...
# 16  Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...
# 17  PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...
# 18  Venkatalakshmi Pedireddy\n\nSoftware Developer...
# 19  Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...
# 20  KAMALAKAR REDDY. A \n\nLinked In: https://www....
# 21  SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...
# 22  Naveen Sadhu\n\n\n\n\n\nTitle: software develo...
# 23  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...
# 24  Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 25  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...
# 26  Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 27  Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...
# 28  SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...
# 29  HARIPRIYA BATTINA \n\nExperience as UI Develop...
# 30  KAMBALLA PRADEEP                              ...
# 31  ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...
# 32  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...
# 33  Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...
# 34  SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...
# 35  RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...
# 36  SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...
# 37  resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...
# 38  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...
# 39  BUDDHA VAMSI                                  ...
# 40  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...
# 41  G Himaja\n\n                                  ...
# 42  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 43  Vinay kumar .v\nWorkday Functional Consultant\...
# 44  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 45  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...
# 46  Srikanth (WORKDAY hCM Consultant)\t           ...
# 47  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...
# 48  Workday HCM  Techno functional Consultant     ...
# 49  Mooraboyina Guravaiah\n\nWorkday Integration S...
# 50  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...
# 51  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...

# %%
resume_data.to_csv('Raw_Resume.csv' , index=False)

# %%
resume_data.to_csv('Raw_resume.csv')
resume_data
# Out:
#                            Category  \
# 0                        Internship
# 1                        Internship
# 2                Peoplesoft resumes
# 3                Peoplesoft resumes
# 4                Peoplesoft resumes
# 5                Peoplesoft resumes
# 6                Peoplesoft resumes
# 7                Peoplesoft resumes
# 8                Peoplesoft resumes
# 9                Peoplesoft resumes
# 10               Peoplesoft resumes
# 11               Peoplesoft resumes
# 12               React JS developer
# 13               React JS developer
# 14               React JS developer
# 15               React JS developer
# 16               React JS developer
# 17               React JS developer
# 18               React JS developer
# 19               React JS developer
# 20               React JS developer
# 21               React JS developer
# 22               React JS developer
# 23               React JS developer
# 24               React JS developer
# 25               React JS developer
# 26               React JS developer
# 27               React JS developer
# 28               React JS developer
# 29               React JS developer
# 30  SQL Developer Lightning insight
# 31  SQL Developer Lightning insight
# 32  SQL Developer Lightning insight
# 33  SQL Developer Lightning insight
# 34  SQL Developer Lightning insight
# 35  SQL Developer Lightning insight
# 36  SQL Developer Lightning insight
# 37  SQL Developer Lightning insight
# 38  SQL Developer Lightning insight
# 39  SQL Developer Lightning insight
# 40  SQL Developer Lightning insight
# 41                  workday resumes
# 42                  workday resumes
# 43                  workday resumes
# 44                  workday resumes
# 45                  workday resumes
# 46                  workday resumes
# 47                  workday resumes
# 48                  workday resumes
# 49                  workday resumes
# 50                  workday resumes
# 51                  workday resumes
#
#                                           Raw_Details
# 0   SUSOVAN  BAG   \n\nSeeking  a  challenging  po...
# 1   Name: Ravali P \n\n\n\n                       ...
# 2   PeopleSoft Administration\n\n \n\nVivekanand S...
# 3   Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...
# 4   SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...
# 5   C O N T A C T :\n\n\n\nAddress: Manyata Tech P...
# 6   PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...
# 7   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# 8   Hari Narayana \t\t              \n\n\t\n\n\n\n...
# 9   Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...
# 10  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...
# 11  Classification: Internal\n\nClassification: In...
# 12  MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...
# 13  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...
# 14  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...
# 15  MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...
# 16  Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...
# 17  PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...
# 18  Venkatalakshmi Pedireddy\n\nSoftware Developer...
# 19  Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...
# 20  KAMALAKAR REDDY. A \n\nLinked In: https://www....
# 21  SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...
# 22  Naveen Sadhu\n\n\n\n\n\nTitle: software develo...
# 23  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...
# 24  Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 25  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...
# 26  Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 27  Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...
# 28  SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...
# 29  HARIPRIYA BATTINA \n\nExperience as UI Develop...
# 30  KAMBALLA PRADEEP                              ...
# 31  ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...
# 32  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...
# 33  Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...
# 34  SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...
# 35  RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...
# 36  SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...
# 37  resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...
# 38  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...
# 39  BUDDHA VAMSI                                  ...
# 40  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...
# 41  G Himaja\n\n                                  ...
# 42  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 43  Vinay kumar .v\nWorkday Functional Consultant\...
# 44  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 45  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...
# 46  Srikanth (WORKDAY hCM Consultant)\t           ...
# 47  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...
# 48  Workday HCM  Techno functional Consultant     ...
# 49  Mooraboyina Guravaiah\n\nWorkday Integration S...
# 50  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...
# 51  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...

# %%
resume_data['Raw_Details']
# Out:
# 0     SUSOVAN  BAG   \n\nSeeking  a  challenging  po...
# 1     Name: Ravali P \n\n\n\n                       ...
# 2     PeopleSoft Administration\n\n \n\nVivekanand S...
# 3     Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...
# 4     SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...
# 5     C O N T A C T :\n\n\n\nAddress: Manyata Tech P...
# 6     PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...
# 7     Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# 8     Hari Narayana \t\t              \n\n\t\n\n\n\n...
# 9     Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...
# 10    Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...
# 11    Classification: Internal\n\nClassification: In...
# 12    MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...
# 13    Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...
# 14    Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...
# 15    MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...
# 16    Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...
# 17    PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...
# 18    Venkatalakshmi Pedireddy\n\nSoftware Developer...
# 19    Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...
# 20    KAMALAKAR REDDY. A \n\nLinked In: https://www....
# 21    SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...
# 22    Naveen Sadhu\n\n\n\n\n\nTitle: software develo...
# 23    MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...
# 24    Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 25    KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...
# 26    Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 27    Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...
# 28    SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...
# 29    HARIPRIYA BATTINA \n\nExperience as UI Develop...
# 30    KAMBALLA PRADEEP                              ...
# 31    ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...
# 32    SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...
# 33    Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...
# 34    SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...
# 35    RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...
# 36    SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...
# 37    resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...
# 38    Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...
# 39    BUDDHA VAMSI                                  ...
# 40    Aradhana Tripathi\n\n\n\nCurrent Location: Gac...
# 41    G Himaja\n\n                                  ...
# 42    WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 43    Vinay kumar .v\nWorkday Functional Consultant\...
# 44    Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 45    VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...
# 46    Srikanth (WORKDAY hCM Consultant)\t           ...
# 47    Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...
# 48    Workday HCM  Techno functional Consultant     ...
# 49    Mooraboyina Guravaiah\n\nWorkday Integration S...
# 50    JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...
# 51    Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...
# Name: Raw_Details, dtype: object

# %%
resume_data[resume_data.Category == 'Internship']
# Out:
#      Category                                        Raw_Details
# 0  Internship  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...
# 1  Internship  Name: Ravali P \n\n\n\n                       ...

# %%
resume_data[resume_data.Category == 'Peoplesoft resumes']
# Out:
#               Category                                        Raw_Details
# 2   Peoplesoft resumes  PeopleSoft Administration\n\n \n\nVivekanand S...
# 3   Peoplesoft resumes  Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...
# 4   Peoplesoft resumes  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...
# 5   Peoplesoft resumes  C O N T A C T :\n\n\n\nAddress: Manyata Tech P...
# 6   Peoplesoft resumes  PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...
# 7   Peoplesoft resumes  Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# 8   Peoplesoft resumes  Hari Narayana \t\t              \n\n\t\n\n\n\n...
# 9   Peoplesoft resumes  Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...
# 10  Peoplesoft resumes  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...
# 11  Peoplesoft resumes  Classification: Internal\n\nClassification: In...

# %%
resume_data[resume_data.Category == 'React JS developer']
# Out:
#               Category                                        Raw_Details
# 12  React JS developer  MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...
# 13  React JS developer  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...
# 14  React JS developer  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...
# 15  React JS developer  MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...
# 16  React JS developer  Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...
# 17  React JS developer  PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...
# 18  React JS developer  Venkatalakshmi Pedireddy\n\nSoftware Developer...
# 19  React JS developer  Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...
# 20  React JS developer  KAMALAKAR REDDY. A \n\nLinked In: https://www....
# 21  React JS developer  SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...
# 22  React JS developer  Naveen Sadhu\n\n\n\n\n\nTitle: software develo...
# 23  React JS developer  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...
# 24  React JS developer  Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 25  React JS developer  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...
# 26  React JS developer  Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 27  React JS developer  Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...
# 28  React JS developer  SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...
# 29  React JS developer  HARIPRIYA BATTINA \n\nExperience as UI Develop...

# %%
resume_data[resume_data.Category == 'SQL Developer Lightning insight']
# Out:
#                            Category  \
# 30  SQL Developer Lightning insight
# 31  SQL Developer Lightning insight
# 32  SQL Developer Lightning insight
# 33  SQL Developer Lightning insight
# 34  SQL Developer Lightning insight
# 35  SQL Developer Lightning insight
# 36  SQL Developer Lightning insight
# 37  SQL Developer Lightning insight
# 38  SQL Developer Lightning insight
# 39  SQL Developer Lightning insight
# 40  SQL Developer Lightning insight
#
#                                           Raw_Details
# 30  KAMBALLA PRADEEP                              ...
# 31  ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...
# 32  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...
# 33  Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...
# 34  SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...
# 35  RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...
# 36  SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...
# 37  resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...
# 38  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...
# 39  BUDDHA VAMSI                                  ...
# 40  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...

# %%
resume_data[resume_data.Category == 'workday resumes']
# Out:
#            Category                                        Raw_Details
# 41  workday resumes  G Himaja\n\n                                  ...
# 42  workday resumes  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 43  workday resumes  Vinay kumar .v\nWorkday Functional Consultant\...
# 44  workday resumes  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 45  workday resumes  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...
# 46  workday resumes  Srikanth (WORKDAY hCM Consultant)\t           ...
# 47  workday resumes  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...
# 48  workday resumes  Workday HCM  Techno functional Consultant     ...
# 49  workday resumes  Mooraboyina Guravaiah\n\nWorkday Integration S...
# 50  workday resumes  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...
# 51  workday resumes  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...

# %%
resume_data.isnull().sum()
# Out:
# Category       0
# Raw_Details    0
# dtype: int64

# %%
resume_data['Word_Count'] = resume_data['Raw_Details'].apply(lambda x: len(str(x).split(" ")))
resume_data[['Raw_Details','Word_Count']].head()
# Out:
# <ipython-input-159-c3c41ceb82bf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resume_data['Word_Count'] = resume_data['Raw_Details'].apply(lambda x: len(str(x).split(" ")))
#                                          Raw_Details  Word_Count
# 0  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...         533
# 1  Name: Ravali P \n\n\n\n                       ...        1795
# 2  PeopleSoft Administration\n\n \n\nVivekanand S...        2585
# 3  Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...         433
# 4  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...         455

# %%
resume_data['Char_Count'] = resume_data['Raw_Details'].str.len()
resume_data[['Raw_Details','Char_Count']].head()
# Out:
# <ipython-input-160-c806985e2334>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resume_data['Char_Count'] = resume_data['Raw_Details'].str.len()
#                                          Raw_Details  Char_Count
# 0  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...        1901
# 1  Name: Ravali P \n\n\n\n                       ...        6175
# 2  PeopleSoft Administration\n\n \n\nVivekanand S...       16112
# 3  Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...        3669
# 4  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...        3800

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
resume_data['Stopwords'] = resume_data['Raw_Details'].apply(lambda x: len([x for x in x.split() if x in stop]))
resume_data[['Raw_Details','Stopwords']].head()
# Out:
# <ipython-input-162-614d83cb1a8d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resume_data['Stopwords'] = resume_data['Raw_Details'].apply(lambda x: len([x for x in x.split() if x in stop]))
#                                          Raw_Details  Stopwords
# 0  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...         39
# 1  Name: Ravali P \n\n\n\n                       ...        179
# 2  PeopleSoft Administration\n\n \n\nVivekanand S...        520
# 3  Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...         84
# 4  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...         86

# %%
resume_data['Numerics'] = resume_data['Raw_Details'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
resume_data[['Raw_Details','Numerics']].head()
# Out:
# <ipython-input-163-218ef16e0d5a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resume_data['Numerics'] = resume_data['Raw_Details'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
#                                          Raw_Details  Numerics
# 0  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...         0
# 1  Name: Ravali P \n\n\n\n                       ...        12
# 2  PeopleSoft Administration\n\n \n\nVivekanand S...        17
# 3  Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...        13
# 4  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...        15

# %%
resume_data
# Out:
#                            Category  \
# 0                        Internship
# 1                        Internship
# 2                Peoplesoft resumes
# 3                Peoplesoft resumes
# 4                Peoplesoft resumes
# 5                Peoplesoft resumes
# 6                Peoplesoft resumes
# 7                Peoplesoft resumes
# 8                Peoplesoft resumes
# 9                Peoplesoft resumes
# 10               Peoplesoft resumes
# 11               Peoplesoft resumes
# 12               React JS developer
# 13               React JS developer
# 14               React JS developer
# 15               React JS developer
# 16               React JS developer
# 17               React JS developer
# 18               React JS developer
# 19               React JS developer
# 20               React JS developer
# 21               React JS developer
# 22               React JS developer
# 23               React JS developer
# 24               React JS developer
# 25               React JS developer
# 26               React JS developer
# 27               React JS developer
# 28               React JS developer
# 29               React JS developer
# 30  SQL Developer Lightning insight
# 31  SQL Developer Lightning insight
# 32  SQL Developer Lightning insight
# 33  SQL Developer Lightning insight
# 34  SQL Developer Lightning insight
# 35  SQL Developer Lightning insight
# 36  SQL Developer Lightning insight
# 37  SQL Developer Lightning insight
# 38  SQL Developer Lightning insight
# 39  SQL Developer Lightning insight
# 40  SQL Developer Lightning insight
# 41                  workday resumes
# 42                  workday resumes
# 43                  workday resumes
# 44                  workday resumes
# 45                  workday resumes
# 46                  workday resumes
# 47                  workday resumes
# 48                  workday resumes
# 49                  workday resumes
# 50                  workday resumes
# 51                  workday resumes
#
#                                           Raw_Details  Word_Count  Char_Count  \
# 0   SUSOVAN  BAG   \n\nSeeking  a  challenging  po...         533        1901
# 1   Name: Ravali P \n\n\n\n                       ...        1795        6175
# 2   PeopleSoft Administration\n\n \n\nVivekanand S...        2585       16112
# 3   Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...         433        3669
# 4   SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...         455        3800
# 5   C O N T A C T :\n\n\n\nAddress: Manyata Tech P...         356        2150
# 6   PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...         918        7943
# 7   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...        1023        8010
# 8   Hari Narayana \t\t              \n\n\t\n\n\n\n...         448        3714
# 9   Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...         540        3577
# 10  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...         363        2852
# 11  Classification: Internal\n\nClassification: In...         558        4917
# 12  MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...         777        3273
# 13  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...         435        3299
# 14  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...         719        5527
# 15  MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...         945        2967
# 16  Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...         524        4005
# 17  PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...         502        3132
# 18  Venkatalakshmi Pedireddy\n\nSoftware Developer...         264        2356
# 19  Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...         194        1773
# 20  KAMALAKAR REDDY. A \n\nLinked In: https://www....         357        2672
# 21  SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...         474        3111
# 22  Naveen Sadhu\n\n\n\n\n\nTitle: software develo...         253        1789
# 23  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...         945        2965
# 24  Ui-Developer/ React JS Developer \n\nNAME: KRI...         361        3700
# 25  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...         496        3001
# 26  Ui-Developer/ React JS Developer \n\nNAME: KRI...         361        3702
# 27  Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...         181        1925
# 28  SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...         349        3156
# 29  HARIPRIYA BATTINA \n\nExperience as UI Develop...         404        2669
# 30  KAMBALLA PRADEEP                              ...         733        4837
# 31  ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...         645        4433
# 32  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...         532        4176
# 33  Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...        1074        6686
# 34  SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...         553        3704
# 35  RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...         576        4022
# 36  SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...         604        4379
# 37  resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...         733        4625
# 38  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...        1105        4957
# 39  BUDDHA VAMSI                                  ...         394        3070
# 40  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...         664        5161
# 41  G Himaja\n\n                                  ...        1317        5736
# 42  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...        1076        8329
# 43  Vinay kumar .v\nWorkday Functional Consultant\...         702        5126
# 44  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...         716        5951
# 45  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...         494        4212
# 46  Srikanth (WORKDAY hCM Consultant)\t           ...        1063        6737
# 47  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...         676        4707
# 48  Workday HCM  Techno functional Consultant     ...        1334        9183
# 49  Mooraboyina Guravaiah\n\nWorkday Integration S...        1210        6934
# 50  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...         485        4761
# 51  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...         955        6542
#
#     Stopwords  Numerics
# 0          39         0
# 1         179        12
# 2         520        17
# 3          84        13
# 4          86        15
# 5          42         8
# 6         225         4
# 7         190         4
# 8          88        13
# 9         136         3
# 10         98         4
# 11        114         7
# 12         70         5
# 13         86         4
# 14        216         2
# 15         67         4
# 16        138         6
# 17         86         2
# 18         43         1
# 19         51         8
# 20         48         8
# 21         64         9
# 22         58         1
# 23         67         4
# 24        112         2
# 25         66         9
# 26        112         2
# 27         34         7
# 28         93         5
# 29        106         6
# 30        160         5
# 31        124         3
# 32        138         3
# 33        194         5
# 34        116         4
# 35        134         2
# 36        127         1
# 37        161         4
# 38        151         8
# 39         50        10
# 40        146         6
# 41        157         2
# 42        236         6
# 43        150         2
# 44        161         1
# 45        100         2
# 46        194         9
# 47        126         1
# 48        341         7
# 49        214         1
# 50        112         8
# 51        216         6

# %% [markdown]
# **Preprocesses  a sentence by performing various text cleaning and filtering operations.**

# %%
from nltk.classify.rte_classify import RegexpTokenizer
def preprocess(sentence):
  sentence = str(sentence) #Converts the input sentence to a string data type
  sentence = sentence.lower() #Converts all characters in the sentence to lowercase.
  sentence = sentence.replace('{html}'," ") # Removes the string '{html}' from the sentence.
  cleanr = re.compile('<.*?>') #Compiles a regular expression pattern to match and remove HTML tags.
  cleantext = re.sub(cleanr, '', sentence) #Uses the compiled pattern to remove HTML tags from the sentence.
  rem_url = re.sub(r'http\S+', '',cleantext) # Removes URLs (starting with 'http' or 'https') from the sentence.
  rem_num = re.sub('[0-9]+','',rem_url) #Removes any numeric digits from the sentence.
  tokenizer = RegexpTokenizer(r'\w+') #Creates a tokenizer using a regular expression pattern that matches word characters
  tokens = tokenizer.tokenize(rem_num) # Tokenizes the sentence into individual words using the tokenizer.
  filtered_words = [w for w in tokens if len(w) > 2 if not w in stopwords.words('english')] #Filters out words with a length less than or equal to 2 and removes common English stopwords using the NLTK library.


  return " ".join(filtered_words) #Joins the filtered words back into a single string, separated by a space.

# %%
import re
from nltk.tokenize import RegexpTokenizer
resume_data = pd.read_csv('Raw_Resume.csv')
resume_data['Resume_Details'] = resume_data.Raw_Details.apply(lambda x: preprocess(x))

# %%
resume_data
# Out:
#                            Category  \
# 0                        Internship
# 1                        Internship
# 2                Peoplesoft resumes
# 3                Peoplesoft resumes
# 4                Peoplesoft resumes
# 5                Peoplesoft resumes
# 6                Peoplesoft resumes
# 7                Peoplesoft resumes
# 8                Peoplesoft resumes
# 9                Peoplesoft resumes
# 10               Peoplesoft resumes
# 11               Peoplesoft resumes
# 12               React JS developer
# 13               React JS developer
# 14               React JS developer
# 15               React JS developer
# 16               React JS developer
# 17               React JS developer
# 18               React JS developer
# 19               React JS developer
# 20               React JS developer
# 21               React JS developer
# 22               React JS developer
# 23               React JS developer
# 24               React JS developer
# 25               React JS developer
# 26               React JS developer
# 27               React JS developer
# 28               React JS developer
# 29               React JS developer
# 30  SQL Developer Lightning insight
# 31  SQL Developer Lightning insight
# 32  SQL Developer Lightning insight
# 33  SQL Developer Lightning insight
# 34  SQL Developer Lightning insight
# 35  SQL Developer Lightning insight
# 36  SQL Developer Lightning insight
# 37  SQL Developer Lightning insight
# 38  SQL Developer Lightning insight
# 39  SQL Developer Lightning insight
# 40  SQL Developer Lightning insight
# 41                  workday resumes
# 42                  workday resumes
# 43                  workday resumes
# 44                  workday resumes
# 45                  workday resumes
# 46                  workday resumes
# 47                  workday resumes
# 48                  workday resumes
# 49                  workday resumes
# 50                  workday resumes
# 51                  workday resumes
#
#                                           Raw_Details  \
# 0   SUSOVAN  BAG   \n\nSeeking  a  challenging  po...
# 1   Name: Ravali P \n\n\n\n                       ...
# 2   PeopleSoft Administration\n\n \n\nVivekanand S...
# 3   Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...
# 4   SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...
# 5   C O N T A C T :\n\n\n\nAddress: Manyata Tech P...
# 6   PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...
# 7   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# 8   Hari Narayana \t\t              \n\n\t\n\n\n\n...
# 9   Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...
# 10  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...
# 11  Classification: Internal\n\nClassification: In...
# 12  MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...
# 13  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...
# 14  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...
# 15  MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...
# 16  Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...
# 17  PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...
# 18  Venkatalakshmi Pedireddy\n\nSoftware Developer...
# 19  Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...
# 20  KAMALAKAR REDDY. A \n\nLinked In: https://www....
# 21  SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...
# 22  Naveen Sadhu\n\n\n\n\n\nTitle: software develo...
# 23  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...
# 24  Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 25  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...
# 26  Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 27  Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...
# 28  SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...
# 29  HARIPRIYA BATTINA \n\nExperience as UI Develop...
# 30  KAMBALLA PRADEEP                              ...
# 31  ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...
# 32  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...
# 33  Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...
# 34  SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...
# 35  RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...
# 36  SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...
# 37  resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...
# 38  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...
# 39  BUDDHA VAMSI                                  ...
# 40  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...
# 41  G Himaja\n\n                                  ...
# 42  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 43  Vinay kumar .v\nWorkday Functional Consultant\...
# 44  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 45  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...
# 46  Srikanth (WORKDAY hCM Consultant)\t           ...
# 47  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...
# 48  Workday HCM  Techno functional Consultant     ...
# 49  Mooraboyina Guravaiah\n\nWorkday Integration S...
# 50  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...
# 51  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...
#
#                                        Resume_Details
# 0   susovan bag seeking challenging position field...
# 1   name ravali curriculum vitae specialization co...
# 2   peoplesoft administration vivekanand sayana ca...
# 3   murali professional summary years experience p...
# 4   sirazuddin bangalore india sirazuddin bangalor...
# 5   address manyata tech park nagavara bangalore l...
# 6   peoplesoft admin varkala vikas career objectiv...
# 7   anubhav kumar singh core competencies scriptin...
# 8   hari narayana professional summary years exper...
# 9   priyabrata hota career objective pursuing peop...
# 10  tanna sujatha objective seeking challenging ro...
# 11  classification internal classification interna...
# 12  khizaruddin rauf experience currently working ...
# 13  ranga gaganam professional summary professiona...
# 14  kotani durga prasad objective aspirant positio...
# 15  mareedu lokesh babu professional overview arou...
# 16  kanumuru deepak reddy career objective secure ...
# 17  pragnya pattnaik expertise around years experi...
# 18  venkatalakshmi pedireddy software developer ex...
# 19  pranish sonone career summary experience years...
# 20  kamalakar reddy linked professional summary ye...
# 21  shaik abdul sharuk years experience wipro care...
# 22  naveen sadhu title software developer location...
# 23  mareedu lokesh babu professional overview arou...
# 24  developer react developer name krishna profess...
# 25  kambala sai surendra summary project basic kno...
# 26  developer react developer name krishna profess...
# 27  thirupathamma balla summary year experience re...
# 28  sarala madasu sarala madasu sri geethika prest...
# 29  haripriya battina experience developer reactjs...
# 30  kamballa pradeep synopsis looking forward aspi...
# 31  anil kumar maddukuri sql msbi developer summar...
# 32  sql msbi developer sql msbi developer vinod ku...
# 33  name ramesh career objective contribute organi...
# 34  sql server developer syam kumar professional s...
# 35  raju pavana kumari professional summary years ...
# 36  sql developer name bandi prem sai career objec...
# 37  resume ramalakshmi career objective profession...
# 38  resume name neeraj mishra experience summary y...
# 39  buddha vamsi career objective years experience...
# 40  aradhana tripathi current location gachibowli ...
# 41  himaja career objective work towards achieving...
# 42  workday hcm fcm name kumar role workday consul...
# 43  vinay kumar workday functional consultant expe...
# 44  ramesh workday hcm consultant professional sum...
# 45  venkata saikrishna workday consultant profssio...
# 46  srikanth workday hcm consultant seeking suitab...
# 47  name gopi krishna reddy professional summery w...
# 48  workday hcm techno functional consultant rahul...
# 49  mooraboyina guravaiah workday integration spec...
# 50  jyoti verma professional summary professional ...
# 51  chinna subbarayudu dob march nationality india...

# %%
resume_data.drop(['Raw_Details'], axis = 1, inplace = True)
resume_data
# Out:
#                            Category  \
# 0                        Internship
# 1                        Internship
# 2                Peoplesoft resumes
# 3                Peoplesoft resumes
# 4                Peoplesoft resumes
# 5                Peoplesoft resumes
# 6                Peoplesoft resumes
# 7                Peoplesoft resumes
# 8                Peoplesoft resumes
# 9                Peoplesoft resumes
# 10               Peoplesoft resumes
# 11               Peoplesoft resumes
# 12               React JS developer
# 13               React JS developer
# 14               React JS developer
# 15               React JS developer
# 16               React JS developer
# 17               React JS developer
# 18               React JS developer
# 19               React JS developer
# 20               React JS developer
# 21               React JS developer
# 22               React JS developer
# 23               React JS developer
# 24               React JS developer
# 25               React JS developer
# 26               React JS developer
# 27               React JS developer
# 28               React JS developer
# 29               React JS developer
# 30  SQL Developer Lightning insight
# 31  SQL Developer Lightning insight
# 32  SQL Developer Lightning insight
# 33  SQL Developer Lightning insight
# 34  SQL Developer Lightning insight
# 35  SQL Developer Lightning insight
# 36  SQL Developer Lightning insight
# 37  SQL Developer Lightning insight
# 38  SQL Developer Lightning insight
# 39  SQL Developer Lightning insight
# 40  SQL Developer Lightning insight
# 41                  workday resumes
# 42                  workday resumes
# 43                  workday resumes
# 44                  workday resumes
# 45                  workday resumes
# 46                  workday resumes
# 47                  workday resumes
# 48                  workday resumes
# 49                  workday resumes
# 50                  workday resumes
# 51                  workday resumes
#
#                                        Resume_Details
# 0   susovan bag seeking challenging position field...
# 1   name ravali curriculum vitae specialization co...
# 2   peoplesoft administration vivekanand sayana ca...
# 3   murali professional summary years experience p...
# 4   sirazuddin bangalore india sirazuddin bangalor...
# 5   address manyata tech park nagavara bangalore l...
# 6   peoplesoft admin varkala vikas career objectiv...
# 7   anubhav kumar singh core competencies scriptin...
# 8   hari narayana professional summary years exper...
# 9   priyabrata hota career objective pursuing peop...
# 10  tanna sujatha objective seeking challenging ro...
# 11  classification internal classification interna...
# 12  khizaruddin rauf experience currently working ...
# 13  ranga gaganam professional summary professiona...
# 14  kotani durga prasad objective aspirant positio...
# 15  mareedu lokesh babu professional overview arou...
# 16  kanumuru deepak reddy career objective secure ...
# 17  pragnya pattnaik expertise around years experi...
# 18  venkatalakshmi pedireddy software developer ex...
# 19  pranish sonone career summary experience years...
# 20  kamalakar reddy linked professional summary ye...
# 21  shaik abdul sharuk years experience wipro care...
# 22  naveen sadhu title software developer location...
# 23  mareedu lokesh babu professional overview arou...
# 24  developer react developer name krishna profess...
# 25  kambala sai surendra summary project basic kno...
# 26  developer react developer name krishna profess...
# 27  thirupathamma balla summary year experience re...
# 28  sarala madasu sarala madasu sri geethika prest...
# 29  haripriya battina experience developer reactjs...
# 30  kamballa pradeep synopsis looking forward aspi...
# 31  anil kumar maddukuri sql msbi developer summar...
# 32  sql msbi developer sql msbi developer vinod ku...
# 33  name ramesh career objective contribute organi...
# 34  sql server developer syam kumar professional s...
# 35  raju pavana kumari professional summary years ...
# 36  sql developer name bandi prem sai career objec...
# 37  resume ramalakshmi career objective profession...
# 38  resume name neeraj mishra experience summary y...
# 39  buddha vamsi career objective years experience...
# 40  aradhana tripathi current location gachibowli ...
# 41  himaja career objective work towards achieving...
# 42  workday hcm fcm name kumar role workday consul...
# 43  vinay kumar workday functional consultant expe...
# 44  ramesh workday hcm consultant professional sum...
# 45  venkata saikrishna workday consultant profssio...
# 46  srikanth workday hcm consultant seeking suitab...
# 47  name gopi krishna reddy professional summery w...
# 48  workday hcm techno functional consultant rahul...
# 49  mooraboyina guravaiah workday integration spec...
# 50  jyoti verma professional summary professional ...
# 51  chinna subbarayudu dob march nationality india...

# %%
resume_data.to_csv('Cleaned_Resumes.csv', index = False)

# %%
resume_data = pd.read_csv('Cleaned_Resumes.csv')
resume_data
# Out:
#                            Category  \
# 0                        Internship
# 1                        Internship
# 2                Peoplesoft resumes
# 3                Peoplesoft resumes
# 4                Peoplesoft resumes
# 5                Peoplesoft resumes
# 6                Peoplesoft resumes
# 7                Peoplesoft resumes
# 8                Peoplesoft resumes
# 9                Peoplesoft resumes
# 10               Peoplesoft resumes
# 11               Peoplesoft resumes
# 12               React JS developer
# 13               React JS developer
# 14               React JS developer
# 15               React JS developer
# 16               React JS developer
# 17               React JS developer
# 18               React JS developer
# 19               React JS developer
# 20               React JS developer
# 21               React JS developer
# 22               React JS developer
# 23               React JS developer
# 24               React JS developer
# 25               React JS developer
# 26               React JS developer
# 27               React JS developer
# 28               React JS developer
# 29               React JS developer
# 30  SQL Developer Lightning insight
# 31  SQL Developer Lightning insight
# 32  SQL Developer Lightning insight
# 33  SQL Developer Lightning insight
# 34  SQL Developer Lightning insight
# 35  SQL Developer Lightning insight
# 36  SQL Developer Lightning insight
# 37  SQL Developer Lightning insight
# 38  SQL Developer Lightning insight
# 39  SQL Developer Lightning insight
# 40  SQL Developer Lightning insight
# 41                  workday resumes
# 42                  workday resumes
# 43                  workday resumes
# 44                  workday resumes
# 45                  workday resumes
# 46                  workday resumes
# 47                  workday resumes
# 48                  workday resumes
# 49                  workday resumes
# 50                  workday resumes
# 51                  workday resumes
#
#                                        Resume_Details
# 0   susovan bag seeking challenging position field...
# 1   name ravali curriculum vitae specialization co...
# 2   peoplesoft administration vivekanand sayana ca...
# 3   murali professional summary years experience p...
# 4   sirazuddin bangalore india sirazuddin bangalor...
# 5   address manyata tech park nagavara bangalore l...
# 6   peoplesoft admin varkala vikas career objectiv...
# 7   anubhav kumar singh core competencies scriptin...
# 8   hari narayana professional summary years exper...
# 9   priyabrata hota career objective pursuing peop...
# 10  tanna sujatha objective seeking challenging ro...
# 11  classification internal classification interna...
# 12  khizaruddin rauf experience currently working ...
# 13  ranga gaganam professional summary professiona...
# 14  kotani durga prasad objective aspirant positio...
# 15  mareedu lokesh babu professional overview arou...
# 16  kanumuru deepak reddy career objective secure ...
# 17  pragnya pattnaik expertise around years experi...
# 18  venkatalakshmi pedireddy software developer ex...
# 19  pranish sonone career summary experience years...
# 20  kamalakar reddy linked professional summary ye...
# 21  shaik abdul sharuk years experience wipro care...
# 22  naveen sadhu title software developer location...
# 23  mareedu lokesh babu professional overview arou...
# 24  developer react developer name krishna profess...
# 25  kambala sai surendra summary project basic kno...
# 26  developer react developer name krishna profess...
# 27  thirupathamma balla summary year experience re...
# 28  sarala madasu sarala madasu sri geethika prest...
# 29  haripriya battina experience developer reactjs...
# 30  kamballa pradeep synopsis looking forward aspi...
# 31  anil kumar maddukuri sql msbi developer summar...
# 32  sql msbi developer sql msbi developer vinod ku...
# 33  name ramesh career objective contribute organi...
# 34  sql server developer syam kumar professional s...
# 35  raju pavana kumari professional summary years ...
# 36  sql developer name bandi prem sai career objec...
# 37  resume ramalakshmi career objective profession...
# 38  resume name neeraj mishra experience summary y...
# 39  buddha vamsi career objective years experience...
# 40  aradhana tripathi current location gachibowli ...
# 41  himaja career objective work towards achieving...
# 42  workday hcm fcm name kumar role workday consul...
# 43  vinay kumar workday functional consultant expe...
# 44  ramesh workday hcm consultant professional sum...
# 45  venkata saikrishna workday consultant profssio...
# 46  srikanth workday hcm consultant seeking suitab...
# 47  name gopi krishna reddy professional summery w...
# 48  workday hcm techno functional consultant rahul...
# 49  mooraboyina guravaiah workday integration spec...
# 50  jyoti verma professional summary professional ...
# 51  chinna subbarayudu dob march nationality india...

# %%
resume_data.Resume_Details
# Out:
# 0     susovan bag seeking challenging position field...
# 1     name ravali curriculum vitae specialization co...
# 2     peoplesoft administration vivekanand sayana ca...
# 3     murali professional summary years experience p...
# 4     sirazuddin bangalore india sirazuddin bangalor...
# 5     address manyata tech park nagavara bangalore l...
# 6     peoplesoft admin varkala vikas career objectiv...
# 7     anubhav kumar singh core competencies scriptin...
# 8     hari narayana professional summary years exper...
# 9     priyabrata hota career objective pursuing peop...
# 10    tanna sujatha objective seeking challenging ro...
# 11    classification internal classification interna...
# 12    khizaruddin rauf experience currently working ...
# 13    ranga gaganam professional summary professiona...
# 14    kotani durga prasad objective aspirant positio...
# 15    mareedu lokesh babu professional overview arou...
# 16    kanumuru deepak reddy career objective secure ...
# 17    pragnya pattnaik expertise around years experi...
# 18    venkatalakshmi pedireddy software developer ex...
# 19    pranish sonone career summary experience years...
# 20    kamalakar reddy linked professional summary ye...
# 21    shaik abdul sharuk years experience wipro care...
# 22    naveen sadhu title software developer location...
# 23    mareedu lokesh babu professional overview arou...
# 24    developer react developer name krishna profess...
# 25    kambala sai surendra summary project basic kno...
# 26    developer react developer name krishna profess...
# 27    thirupathamma balla summary year experience re...
# 28    sarala madasu sarala madasu sri geethika prest...
# 29    haripriya battina experience developer reactjs...
# 30    kamballa pradeep synopsis looking forward aspi...
# 31    anil kumar maddukuri sql msbi developer summar...
# 32    sql msbi developer sql msbi developer vinod ku...
# 33    name ramesh career objective contribute organi...
# 34    sql server developer syam kumar professional s...
# 35    raju pavana kumari professional summary years ...
# 36    sql developer name bandi prem sai career objec...
# 37    resume ramalakshmi career objective profession...
# 38    resume name neeraj mishra experience summary y...
# 39    buddha vamsi career objective years experience...
# 40    aradhana tripathi current location gachibowli ...
# 41    himaja career objective work towards achieving...
# 42    workday hcm fcm name kumar role workday consul...
# 43    vinay kumar workday functional consultant expe...
# 44    ramesh workday hcm consultant professional sum...
# 45    venkata saikrishna workday consultant profssio...
# 46    srikanth workday hcm consultant seeking suitab...
# 47    name gopi krishna reddy professional summery w...
# 48    workday hcm techno functional consultant rahul...
# 49    mooraboyina guravaiah workday integration spec...
# 50    jyoti verma professional summary professional ...
# 51    chinna subbarayudu dob march nationality india...
# Name: Resume_Details, dtype: object

# %%
Details = resume_data.Resume_Details
Details
# Out:
# 0     susovan bag seeking challenging position field...
# 1     name ravali curriculum vitae specialization co...
# 2     peoplesoft administration vivekanand sayana ca...
# 3     murali professional summary years experience p...
# 4     sirazuddin bangalore india sirazuddin bangalor...
# 5     address manyata tech park nagavara bangalore l...
# 6     peoplesoft admin varkala vikas career objectiv...
# 7     anubhav kumar singh core competencies scriptin...
# 8     hari narayana professional summary years exper...
# 9     priyabrata hota career objective pursuing peop...
# 10    tanna sujatha objective seeking challenging ro...
# 11    classification internal classification interna...
# 12    khizaruddin rauf experience currently working ...
# 13    ranga gaganam professional summary professiona...
# 14    kotani durga prasad objective aspirant positio...
# 15    mareedu lokesh babu professional overview arou...
# 16    kanumuru deepak reddy career objective secure ...
# 17    pragnya pattnaik expertise around years experi...
# 18    venkatalakshmi pedireddy software developer ex...
# 19    pranish sonone career summary experience years...
# 20    kamalakar reddy linked professional summary ye...
# 21    shaik abdul sharuk years experience wipro care...
# 22    naveen sadhu title software developer location...
# 23    mareedu lokesh babu professional overview arou...
# 24    developer react developer name krishna profess...
# 25    kambala sai surendra summary project basic kno...
# 26    developer react developer name krishna profess...
# 27    thirupathamma balla summary year experience re...
# 28    sarala madasu sarala madasu sri geethika prest...
# 29    haripriya battina experience developer reactjs...
# 30    kamballa pradeep synopsis looking forward aspi...
# 31    anil kumar maddukuri sql msbi developer summar...
# 32    sql msbi developer sql msbi developer vinod ku...
# 33    name ramesh career objective contribute organi...
# 34    sql server developer syam kumar professional s...
# 35    raju pavana kumari professional summary years ...
# 36    sql developer name bandi prem sai career objec...
# 37    resume ramalakshmi career objective profession...
# 38    resume name neeraj mishra experience summary y...
# 39    buddha vamsi career objective years experience...
# 40    aradhana tripathi current location gachibowli ...
# 41    himaja career objective work towards achieving...
# 42    workday hcm fcm name kumar role workday consul...
# 43    vinay kumar workday functional consultant expe...
# 44    ramesh workday hcm consultant professional sum...
# 45    venkata saikrishna workday consultant profssio...
# 46    srikanth workday hcm consultant seeking suitab...
# 47    name gopi krishna reddy professional summery w...
# 48    workday hcm techno functional consultant rahul...
# 49    mooraboyina guravaiah workday integration spec...
# 50    jyoti verma professional summary professional ...
# 51    chinna subbarayudu dob march nationality india...
# Name: Resume_Details, dtype: object

# %% [markdown]
# **Joining the list into one String**

# %%
text = ' '.join(Details)
text
# Out:
# 'susovan bag seeking challenging position field science technology utilize skills organization individual growth enhance knowledge academic learning give best organization skills ccna routing switching subnetting programming java html css sql oops algorithms data structures dbms networking linux linux system administration troubleshooting soft skills leadership collaboration good communication customer handling skills languages english fluent hindi fluent bengali native telugu projects smart agriculture built product farmers using iot solution automatic water motor controller iot android api technologies combined automate work water motor controllers using sensors bookstore management interface manage purchase return books books store hotel management system dec designed front end module hotel management system website using html css online movie ticket booking designed fully functioning website using html css javascript education background lovely professional university punjab india tech computer science engineering gpa sri chaitanya junior college visakhapatnam india intermediate mpc intermediate mrs mariadas school icse hobbies web surfing cricket carrom chess name ravali curriculum vitae specialization computer science engg utilize technical skills achieving target developing best performance organization ion ion degree course college institute university board percentage cgpa year passing cgpacgpa institute technology vtu cgpa diploma aryabharathi polytechnic karnataka state board technical examination bengaluru sslc empress girls high school karnataka secondary education board manual testing skills strong knowledge sdlc concepts extensive knowledge white box testing good knowledge functional testing integration testing extreme knowledge system testing good knowledge adhoc testing reliability testing good knowledge exploratory testing good knowledge stlc concepts good knowledge test cases test scenarios good knowledge globalization testing compatibility testing knowledge regression testing good knowledge test plan goo goo ing goo goo goo goo ing goo goo agile methdology good knowledge scrum methodology expertise sprint planning meeting good knowledge scrum meeting extreme knowledge sprint retrospective meeting good knowledge product backlog meeting bug triage meeting extreme knowledge normalization java skills good knowledge method overloading method overriding good understanding static nonstatic good understanding variables good knowledge constructor good knowledge abstraction good knowledge encapsulation good knowledge inheritance good knowledge collections academic projects projects year completion smart farmland crop prevention animal intrusion detection using cnn library management system training courses training course conducted duration internship zerozilla month industrial exposure industry skills learned zerozilla software company bengaluru webtechnology php sql java full stack achievements certified cyber security training sjbit bengaluru certified volleyball olympics distict level assignements identified functional test cases flipkart com identified integration test cases whatsapp identified integration test cases amazon com found defects usability camaptibility globalization testing strengths iti iti date birth gender female father name fasala reddy languages known english telugu kannada hindi nationality indian address thirumaladevarahalli parthihalli kodigenahalli madhugiri tumkur state karnataka hereby declare mentioned information true best knowledge sincerely ravali place bangalore peoplesoft administration vivekanand sayana career objective valid expertise years peoplesoft hope enhance skill set adding value business enable implementation solutions aid company objectives understanding anticipating needs interests motivations clients deliver time budget quality delivering value improving agility quality reliability professional summary years experience peoplesoft implementation support configuration mig ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
text_tokens = word_tokenize(text)
text_tokens
# Out:
# ['susovan',
#  'bag',
#  'seeking',
#  'challenging',
#  'position',
#  'field',
#  'science',
#  'technology',
#  'utilize',
#  'skills',
#  'organization',
#  'individual',
#  'growth',
#  'enhance',
#  'knowledge',
#  'academic',
#  'learning',
#  'give',
#  'best',
#  'organization',
#  'skills',
#  'ccna',
#  'routing',
#  'switching',
#  'subnetting',
#  'programming',
#  'java',
#  'html',
#  'css',
#  'sql',
#  'oops',
#  'algorithms',
#  'data',
#  'structures',
#  'dbms',
#  'networking',
#  'linux',
#  'linux',
#  'system',
#  'administration',
#  'troubleshooting',
#  'soft',
#  'skills',
#  'leadership',
#  'collaboration',
#  'good',
#  'communication',
#  'customer',
#  'handling',
#  'skills',
#  'languages',
#  'english',
#  'fluent',
#  'hindi',
#  'fluent',
#  'bengali',
#  'native',
#  'telugu',
#  'projects',
#  'smart',
#  'agriculture',
#  'built',
#  'product',
#  'farmers',
#  'using',
#  'iot',
#  'solution',
#  'automatic',
#  'water',
#  'motor',
#  'controller',
#  'iot',
#  'android',
#  'api',
#  'technologies',
#  'combined',
#  'automate',
#  'work',
#  'water',
#  'motor',
#  'controllers',
#  'using',
#  'sensors',
#  'bookstore',
#  'management',
#  'interface',
#  'manage',
#  'purchase',
#  'return',
#  'books',
#  'books',
#  'store',
#  'hotel',
#  'management',
#  'system',
#  'dec',
#  'designed',
#  'front',
#  'end',
#  'module',
#  'hotel',
#  'management',
#  'system',
#  'website',
#  'using',
#  'html',
#  'css',
#  'online',
#  'movie',
#  'ticket',
#  'booking',
#  'designed',
#  'fully',
#  'functioning',
#  'website',
#  'using',
#  'html',
#  'css',
#  'javascript',
#  'education',
#  'background',
#  'lovely',
#  'professional',
#  'university',
#  'punjab',
#  'india',
#  'tech',
#  'computer',
#  'science',
#  'engineering',
#  'gpa',
#  'sri',
#  'chaitanya',
#  'junior',
#  'college',
#  'visakhapatnam',
#  'india',
#  'intermediate',
#  'mpc',
#  'intermediate',
#  'mrs',
#  'mariadas',
#  'school',
#  'icse',
#  'hobbies',
#  'web',
#  'surfing',
#  'cricket',
#  'carrom',
#  'chess',
#  'name',
#  'ravali',
#  'curriculum',
#  'vitae',
#  'specialization',
#  'computer',
#  'science',
#  'engg',
#  'utilize',
#  'technical',
#  'skills',
#  'achieving',
#  'target',
#  'developing',
#  'best',
#  'performance',
#  'organization',
#  'ion',
#  'ion',
#  'degree',
#  'course',
#  'college',
#  'institute',
#  'university',
#  'board',
#  'percentage',
#  'cgpa',
#  'year',
#  'passing',
#  'cgpacgpa',
#  'institute',
#  'technology',
#  'vtu',
#  'cgpa',
#  'diploma',
#  'aryabharathi',
#  'polytechnic',
#  'karnataka',
#  'state',
#  'board',
#  'technical',
#  'examination',
#  'bengaluru',
#  'sslc',
#  'empress',
#  'girls',
#  'high',
#  'school',
#  'karnataka',
#  'secondary',
#  'education',
#  'board',
#  'manual',
#  'testing',
#  'skills',
#  'strong',
#  'knowledge',
#  'sdlc',
#  'concepts',
#  'extensive',
#  'knowledge',
#  'white',
#  'box',
#  'testing',
#  'good',
#  'knowledge',
#  'functional',
#  'testing',
#  'integration',
#  'testing',
#  'extreme',
#  'knowledge',
#  'system',
#  'testing',
#  'good',
#  'knowledge',
#  'adhoc',
#  'testing',
#  'reliability',
#  'testing',
#  'good',
#  'knowledge',
#  'exploratory',
#  'testing',
#  'good',
#  'knowledge',
#  'stlc',
#  'concepts',
#  'good',
#  'knowledge',
#  'test',
#  'cases',
#  'test',
#  'scenarios',
#  'good',
#  'knowledge',
#  'globalization',
#  'testing',
#  'compatibility',
#  'testing',
#  'knowledge',
#  'regression',
#  'testing',
#  'good',
#  'knowledge',
#  'test',
#  'plan',
#  'goo',
#  'goo',
#  'ing',
#  'goo',
#  'goo',
#  'goo',
#  'goo',
#  'ing',
#  'goo',
#  'goo',
#  'agile',
#  'methdology',
#  'good',
#  'knowledge',
#  'scrum',
#  'methodology',
#  'expertise',
#  'sprint',
#  'planning',
#  'meeting',
#  'good',
#  'knowledge',
#  'scrum',
#  'meeting',
#  'extreme',
#  'knowledge',
#  'sprint',
#  'retrospective',
#  'meeting',
#  'good',
#  'knowledge',
#  'product',
#  'backlog',
#  'meeting',
#  'bug',
#  'triage',
#  'meeting',
#  'extreme',
#  'knowledge',
#  'normalization',
#  'java',
#  'skills',
#  'good',
#  'knowledge',
#  'method',
#  'overloading',
#  'method',
#  'overriding',
#  'good',
#  'understanding',
#  'static',
#  'nonstatic',
#  'good',
#  'understanding',
#  'variables',
#  'good',
#  'knowledge',
#  'constructor',
#  'good',
#  'knowledge',
#  'abstraction',
#  'good',
#  'knowledge',
#  'encapsulation',
#  'good',
#  'knowledge',
#  'inheritance',
#  'good',
#  'knowledge',
#  'collections',
#  'academic',
#  'projects',
#  'projects',
#  'year',
#  'completion',
#  'smart',
#  'farmland',
#  'crop',
#  'prevention',
#  'animal',
#  'intrusion',
#  'detection',
#  'using',
#  'cnn',
#  'library',
#  'management',
#  'system',
#  'training',
#  'courses',
#  'training',
#  'course',
#  'conducted',
#  'duration',
#  'internship',
#  'zerozilla',
#  'month',
#  'industrial',
#  'exposure',
#  'industry',
#  'skills',
#  'learned',
#  'zerozilla',
#  'software',
#  'company',
#  'bengaluru',
#  'webtechnology',
#  'php',
#  'sql',
#  'java',
#  'full',
#  'stack',
#  'achievements',
#  'certified',
#  'cyber',
#  'security',
#  'training',
#  'sjbit',
#  'bengaluru',
#  'certified',
#  'volleyball',
#  'olympics',
#  'distict',
#  'level',
#  'assignements',
#  'identified',
#  'functional',
#  'test',
#  'cases',
#  'flipkart',
#  'com',
#  'identified',
#  'integration',
#  'test',
#  'cases',
#  'whatsapp',
#  'identified',
#  'integration',
#  'test',
#  'cases',
#  'amazon',
#  'com',
#  'found',
#  'defects',
#  'usability',
#  'camaptibility',
#  'globalization',
#  'testing',
#  'strengths',
#  'iti',
#  'iti',
#  'date',
#  'birth',
#  'gender',
#  'female',
#  'father',
#  'name',
#  'fasala',
#  'reddy',
#  'languages',
#  'known',
#  'english',
#  'telugu',
#  'kannada',
#  'hindi',
#  'nationality',
#  'indian',
#  'address',
#  'thirumaladevarahalli',
#  'parthihalli',
#  'kodigenahalli',
#  'madhugiri',
#  'tumkur',
#  'state',
#  'karnataka',
#  'hereby',
#  'declare',
#  'mentioned',
#  'information',
#  'true',
#  'best',
#  'knowledge',
#  'sincerely',
#  'ravali',
#  'place',
#  'bangalore',
#  'peoplesoft',
#  'administration',
#  'vivekanand',
#  'sayana',
#  'career',
#  'objective',
#  'valid',
#  'expertise',
#  'years',
#  'peoplesoft',
#  'hope',
#  'enhance',
#  'skill',
#  'set',
#  'adding',
#  'value',
#  'business',
#  'enable',
#  'implementation',
#  'solutions',
#  'aid',
#  'company',
#  'objectives',
#  'understanding',
#  'anticipating',
#  'needs',
#  'interests',
#  'motivations',
#  'clients',
#  'deliver',
#  'time',
#  'budget',
#  'quality',
#  'delivering',
#  'value',
#  'improving',
#  'agility',
#  'quality',
#  'reliability',
#  'professional',
#  'summary',
#  'years',
#  'experience',
#  'peoplesoft',
#  'implementation',
#  'support',
#  'configuration',
#  'migrations',
#  'maintenance',
#  'administration',
#  'application',
#  'server',
#  'domains',
#  'process',
#  'scheduler',
#  'servers',
#  'web',
#  'server',
#  'domains',
#  'peopletools',
#  'upgrades',
#  'application',
#  'updates',
#  'pum',
#  'ses',
#  'elastic',
#  'search',
#  'experience',
#  'integration',
#  'activities',
#  'various',
#  'peoplesoft',
#  'financials',
#  'hrms',
#  'epm',
#  'fscm',
#  'environments',
#  'extensively',
#  'involved',
#  'resolving',
#  'performance',
#  'issues',
#  'experience',
#  'driving',
#  'infrastructure',
#  'hardware',
#  'upgrades',
#  'disaster',
#  'recovery',
#  'activities',
#  'experience',
#  'health',
#  'check',
#  'peoplesoft',
#  'environments',
#  'experience',
#  'peoplesoft',
#  'database',
#  'refreshes',
#  'production',
#  'development',
#  'testing',
#  'environments',
#  'experience',
#  'performance',
#  'tuning',
#  'application',
#  'servers',
#  'web',
#  'servers',
#  'performed',
#  'full',
#  'life',
#  'cycle',
#  'implementations',
#  'peoplesoft',
#  'implemented',
#  'peoplesoft',
#  'internet',
#  'architecture',
#  'pia',
#  'demo',
#  'test',
#  'development',
#  'production',
#  'instances',
#  'experience',
#  'peoplesoft',
#  'implementation',
#  'peopletools',
#  'fscm',
#  'web',
#  'logic',
#  'tuxedo',
#  'oracle',
#  'oracle',
#  'enterprise',
#  'linux',
#  'windows',
#  'experience',
#  'peoplesoft',
#  'installations',
#  'peopletools',
#  'hcm',
#  'weblogic',
#  'tuxedo',
#  'people',
#  'books',
#  'oracle',
#  'enterprise',
#  'linux',
#  'windows',
#  'experience',
#  'peoplesoft',
#  'installations',
#  'peopletools',
#  'hcm',
#  'weblogic',
#  'tuxedo',
#  'people',
#  'books',
#  'windows',
#  'oracle',
#  'enterprise',
#  'linux',
#  'experience',
#  'peoplesoft',
#  'installations',
#  'peopletools',
#  'fscm',
#  'weblogic',
#  'tuxedo',
#  'people',
#  'books',
#  'windows',
#  'oracle',
#  'enterprise',
#  'linux',
#  'experience',
#  'peoplesoft',
#  'installations',
#  'peopletools',
#  'hcm',
#  'weblogic',
#  'tuxedo',
#  'oracle',
#  'people',
#  'books',
#  'windows',
#  'server',
#  'oracle',
#  'enterprise',
#  'linux',
#  'depth',
#  'experience',
#  'peoplesoft',
#  'update',
#  'manager',
#  'pum',
#  'applying',
#  'peopletools',
#  'patches',
#  'application',
#  'bundles',
#  'peopletools',
#  'hrms',
#  'fscm',
#  'applications',
#  'using',
#  'dpk',
#  'deploy',
#  'pum',
#  'latest',
#  'images',
#  'dpk',
#  'install',
#  'middle',
#  'tier',
#  'app',
#  'tier',
#  'peopletools',
#  'depth',
#  'experience',
#  'integration',
#  'broker',
#  'troubleshooting',
#  'proficiency',
#  'creation',
#  'configuration',
#  'administration',
#  'application',
#  'server',
#  'domains',
#  'process',
#  'scheduler',
#  'domains',
#  'web',
#  'server',
#  'domains',
#  'experience',
#  'reconfiguration',
#  'application',
#  'server',
#  'domains',
#  'process',
#  'scheduler',
#  'server',
#  'domains',
#  'web',
#  'server',
#  'domains',
#  'experience',
#  'project',
#  'migrations',
#  'using',
#  'application',
#  'designer',
#  'data',
#  'migrations',
#  'using',
#  'data',
#  'mover',
#  'experience',
#  'generating',
#  'pre',
#  'compare',
#  'reports',
#  'post',
#  'compare',
#  'reports',
#  'various',
#  'environments',
#  'experience',
#  'setting',
#  'client',
#  'work',
#  'station',
#  'developers',
#  'testers',
#  'experience',
#  'resolving',
#  'developer',
#  'issues',
#  'like',
#  'resetting',
#  'passwords',
#  'locking',
#  'unlocking',
#  'user',
#  'accounts',
#  'maintain',
#  'workflow',
#  'peoplesoft',
#  'users',
#  'worked',
#  'applying',
#  'patches',
#  'bundles',
#  'tax',
#  'updates',
#  'using',
#  'change',
#  'assistant',
#  'peoplesoft',
#  'update',
#  'manager',
#  'pum',
#  'installing',
#  'configuring',
#  'change',
#  'assistant',
#  'apply',
#  'bundles',
#  'tax',
#  'updates',
#  'involved',
#  'setup',
#  'configuration',
#  'integration',
#  'broker',
#  'financials',
#  'hcm',
#  'applications',
#  'maintaining',
#  'integrity',
#  'internal',
#  'consistency',
#  'database',
#  'using',
#  'dddaudit',
#  'sysaudit',
#  'alteraudit',
#  'reports',
#  'periodically',
#  'experience',
#  'load',
#  'balancing',
#  'application',
#  'server',
#  'domains',
#  'process',
#  'scheduler',
#  'servers',
#  'experience',
#  'clearing',
#  'cache',
#  'servers',
#  'application',
#  'server',
#  'domains',
#  'web',
#  'server',
#  'domains',
#  'process',
#  'scheduler',
#  'servers',
#  'regular',
#  'basis',
#  'monitor',
#  'log',
#  'files',
#  'find',
#  'bottleneck',
#  'status',
#  'servers',
#  'experience',
#  'troubleshooting',
#  'data',
#  'mover',
#  'installing',
#  'peoplesoft',
#  'maintaining',
#  'troubleshooting',
#  'various',
#  'servers',
#  'like',
#  'application',
#  'server',
#  'domains',
#  'process',
#  'scheduler',
#  'domains',
#  'web',
#  'server',
#  'domains',
#  'experience',
#  'tuning',
#  'application',
#  'server',
#  'domains',
#  'process',
#  'scheduler',
#  'domains',
#  'web',
#  'server',
#  'domains',
#  'strong',
#  'communication',
#  'collaboration',
#  'team',
#  'building',
#  'inter',
#  'personal',
#  'skills',
#  'good',
#  'team',
#  'player',
#  'proven',
#  'individual',
#  'contributor',
#  'area',
#  'technical',
#  'skills',
#  'technology',
#  'tools',
#  'erp',
#  'tools',
#  'people',
#  'tools',
#  'change',
#  'assistant',
#  'integration',
#  'broker',
#  'application',
#  'designer',
#  'configuration',
#  'manager',
#  'peoplesoft',
#  'update',
#  'manager',
#  'pum',
#  'ses',
#  'data',
#  'mover',
#  'applications',
#  'peoplesoft',
#  'hrms',
#  'fscm',
#  'crm',
#  'application',
#  'server',
#  'tuxedo',
#  'web',
#  'server',
#  'web',
#  'logic',
#  'operating',
#  'systems',
#  'windows',
#  'server',
#  'redhat',
#  'enterprise',
#  'linux',
#  'oracle',
#  'enterprise',
#  'linux',
#  'database',
#  'oracle',
#  'educational',
#  'qualification',
#  'mba',
#  'marketing',
#  'kbn',
#  'college',
#  'nagarjuna',
#  'university',
#  'vijayawada',
#  'bachelor',
#  'science',
#  'srr',
#  'cvr',
#  'college',
#  'nagarjuna',
#  'university',
#  'vijayawada',
#  'professional',
#  'experience',
#  'worked',
#  'peoplesoft',
#  'systems',
#  'administrator',
#  'capgemini',
#  'technology',
#  'services',
#  'india',
#  'limited',
#  'feb',
#  'sept',
#  'worked',
#  'peoplesoft',
#  'systems',
#  'administrator',
#  'cognizant',
#  'technology',
#  'solutions',
#  'india',
#  'pvt',
#  'ltd',
#  'oct',
#  'sept',
#  'worked',
#  'associate',
#  'peoplesoft',
#  'administrator',
#  'innovative',
#  'solutions',
#  'pvt',
#  'ltd',
#  'jan',
#  'oct',
#  'project',
#  'experience',
#  'achievement',
#  'client',
#  'disney',
#  'fox',
#  'entertainment',
#  'allegis',
#  'environment',
#  'hcm',
#  'fscm',
#  'elm',
#  'people',
#  'tools',
#  'oracle',
#  'weblogic',
#  'tuxedo',
#  'red',
#  'hat',
#  'enterprise',
#  'linux',
#  'role',
#  'peoplesoft',
#  'admin',
#  'peoplesoft',
#  'dba',
#  'duration',
#  'feb',
#  'sept',
#  'roles',
#  'responsibilities',
#  'involved',
#  'peopletools',
#  'upgrade',
#  'peopletools',
#  'involved',
#  'application',
#  'update',
#  'fscm',
#  'fscm',
#  'strong',
#  'experience',
#  'peoplesoft',
#  'pum',
#  'server',
#  'installation',
#  'troubleshooting',
#  'applying',
#  ...]

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tag import pos_tag

def filter_nouns_and_verbs(text):
  sentences = sent_tokenize(text)
  filtered_tokens = []
  for sentence in sentences:
    tokens = word_tokenize(sentence)
    tagged_tokens = pos_tag(tokens)
    filtered_tokens.extend(word for word,pos in tagged_tokens if pos.startswith('NN') or pos.startswith('VB'))
    return filtered_tokens

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
nouns_verbs = filter_nouns_and_verbs(text)
print(nouns_verbs)
# Out:
# ['susovan', 'bag', 'seeking', 'position', 'field', 'science', 'technology', 'skills', 'organization', 'growth', 'enhance', 'knowledge', 'learning', 'organization', 'skills', 'ccna', 'routing', 'switching', 'subnetting', 'programming', 'java', 'html', 'css', 'sql', 'oops', 'structures', 'dbms', 'networking', 'linux', 'linux', 'system', 'administration', 'troubleshooting', 'skills', 'leadership', 'collaboration', 'communication', 'customer', 'handling', 'skills', 'languages', 'fluent', 'hindi', 'fluent', 'bengali', 'telugu', 'projects', 'smart', 'agriculture', 'built', 'product', 'farmers', 'using', 'solution', 'water', 'motor', 'controller', 'iot', 'api', 'technologies', 'combined', 'work', 'water', 'motor', 'controllers', 'using', 'sensors', 'management', 'interface', 'manage', 'purchase', 'return', 'books', 'books', 'store', 'hotel', 'management', 'system', 'dec', 'designed', 'end', 'module', 'hotel', 'management', 'system', 'using', 'movie', 'ticket', 'booking', 'designed', 'functioning', 'using', 'css', 'javascript', 'education', 'background', 'university', 'punjab', 'india', 'tech', 'computer', 'science', 'engineering', 'gpa', 'sri', 'chaitanya', 'college', 'mpc', 'mrs', 'school', 'icse', 'hobbies', 'web', 'surfing', 'cricket', 'carrom', 'chess', 'name', 'ravali', 'curriculum', 'vitae', 'specialization', 'computer', 'science', 'skills', 'achieving', 'target', 'developing', 'performance', 'organization', 'ion', 'ion', 'course', 'college', 'institute', 'university', 'board', 'percentage', 'cgpa', 'year', 'passing', 'cgpacgpa', 'institute', 'technology', 'vtu', 'cgpa', 'diploma', 'aryabharathi', 'karnataka', 'state', 'board', 'examination', 'bengaluru', 'sslc', 'girls', 'school', 'karnataka', 'education', 'board', 'testing', 'skills', 'knowledge', 'sdlc', 'concepts', 'knowledge', 'box', 'testing', 'knowledge', 'testing', 'integration', 'testing', 'extreme', 'knowledge', 'system', 'testing', 'knowledge', 'testing', 'reliability', 'testing', 'knowledge', 'exploratory', 'testing', 'knowledge', 'stlc', 'concepts', 'knowledge', 'test', 'cases', 'test', 'scenarios', 'knowledge', 'globalization', 'testing', 'compatibility', 'testing', 'knowledge', 'regression', 'testing', 'knowledge', 'test', 'plan', 'goo', 'ing', 'goo', 'goo', 'goo', 'goo', 'ing', 'goo', 'methdology', 'knowledge', 'scrum', 'methodology', 'expertise', 'sprint', 'planning', 'meeting', 'knowledge', 'scrum', 'meeting', 'knowledge', 'sprint', 'meeting', 'knowledge', 'product', 'backlog', 'meeting', 'triage', 'meeting', 'knowledge', 'normalization', 'java', 'skills', 'knowledge', 'method', 'overloading', 'overriding', 'understanding', 'variables', 'knowledge', 'constructor', 'knowledge', 'abstraction', 'knowledge', 'encapsulation', 'knowledge', 'inheritance', 'knowledge', 'collections', 'projects', 'projects', 'year', 'completion', 'farmland', 'crop', 'prevention', 'intrusion', 'detection', 'using', 'management', 'system', 'training', 'courses', 'training', 'course', 'conducted', 'duration', 'internship', 'month', 'exposure', 'industry', 'skills', 'learned', 'zerozilla', 'software', 'company', 'bengaluru', 'webtechnology', 'php', 'sql', 'java', 'stack', 'achievements', 'certified', 'security', 'training', 'sjbit', 'bengaluru', 'certified', 'olympics', 'distict', 'level', 'assignements', 'identified', 'test', 'cases', 'flipkart', 'com', 'identified', 'integration', 'test', 'cases', 'whatsapp', 'identified', 'integration', 'test', 'cases', 'amazon', 'com', 'found', 'defects', 'camaptibility', 'globalization', 'testing', 'strengths', 'date', 'birth', 'gender', 'female', 'father', 'name', 'fasala', 'reddy', 'languages', 'known', 'telugu', 'kannada', 'hindi', 'nationality', 'address', 'thirumaladevarahalli', 'parthihalli', 'kodigenahalli', 'madhugiri', 'tumkur', 'state', 'karnataka', 'hereby', 'declare', 'mentioned', 'information', 'knowledge', 'place', 'bangalore', 'administration', 'vivekanand', 'sayana', 'career', 'objective', 'expertise', 'years', 'peoplesoft', 'hope', 'e ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X = cv.fit_transform(nouns_verbs)
sum_words = X.sum(axis=0)

words_freq = [(word,sum_words[0,idx]) for word, idx in cv.vocabulary_.items()]
words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)


wd_df = pd.DataFrame(words_freq)
wd_df.columns = ['Words','Count']
wd_df[0:15]
# Out:
#           Words  Count
# 0    experience    297
# 1         using    253
# 2   application    204
# 3          data    178
# 4       project    177
# 5       reports    170
# 6      business    165
# 7           sql    155
# 8        server    145
# 9     knowledge    136
# 10       skills    118
# 11       system    116
# 12          web    112
# 13      workday    106
# 14       client    105

# %%
text = " ".join(x for x in wd_df.Words)
text
# Out:
# 'experience using application data project reports business sql server knowledge skills system web workday client process working tools creating database integrations development support worked integration servers services involved people created report design used developer role react responsibilities work studio testing team management security date technologies information windows hcm code environment fields oracle production developed core issues css software applications javascript years reporting domains functions html based requirement requirements scheduler developing consultant tables technology end queries languages day custom education till components name systems college test change roles bootstrap engineering performance maintenance description eib projects expertise implementation status job details organization interface fscm objects procedures compensation peoplesoft xml customer load packages peopletools activities hyderabad hands environments transformation troubleshooting indexes university modules documents control ability ssis calculated designed designer tool create views solutions users operating changes writing communication duration building file inbound service updates engine processes connectors writer configuration implemented architecture applying maintain provide designing payroll tech year time pum hrms setup profile connector company level patches pvt analysis configured mysql groups concepts etc databases declaration stored types school check tuning instances tasks source page user query pages document triggers understanding career enterprise broker configuring layout sending redux jquery programming hereby place migrations admin perform enhancements related task xslt rules known manager creation maintaining basis monitoring migration interfaces unit required experienced get develop absence linux administration built industry declare jobs engineer including profiles domain help flow tracking customers joins science hindi computer performed tax monitor existing benefits programs github models advanced cost picof growth solution module board cases tuxedo compare setting installation group finance soap loading matrix plans organizations leave java handling percentage plan training exposure assistant installing files validations scripts providing access summary employee features request sales birt nationality set search resolving health apply player qualification handled installed enhancement staffing aug july account teams requests performing migrating router location employees analyzing excel telugu birth quality internet generating integrity balancing cache bachelor involving error recruiting products insurance keys office shell configurations scripting aws inventory component furnished functionality reactjs track worker records modified position sri institute reddy skill adding bundles app fixes object success understand problem party cloud kumar completed platform jntu mar gathering json framework type areas etl transformations drill analytics constraints sandbox books india gender address value clients financials life cycle post consistency area ltd image troubleshoot sub logic send version supporting conversion output oriented needs debugging title optimization meet presentation care validation traffic dom written clustered container bulk table candidates peci condition ccw field product target find administrator oct feb delivery assign scratch add towards provided scheduling managed bug belief implementing defined needed forms model union builder ssrs intelligence derived merge join sources integrated policies center vendors transporter hierarchies course cgpa conducted bangalore proficiency developers dddaudit sysaudit update vijayawada sept processing generate customizations applied master billing program randstad june notifications bank solving transfer secure identifying male designation size members modifying scheduled months websites commerce part orders stock review world events pack ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS

# %%
def plot_cloud(worldcloud):
  plt.figure(figsize=(15, 30))
  plt.imshow(wordcloud)
  plt.axis("off");

# %%
stopwords=STOPWORDS
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
#  'like',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'same',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'since',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'therefore',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
pip install wordcloud
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.8.2.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.22.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.12.0)

# %%
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(width=3000, height=2000, background_color='black')
wordcloud.generate(text)

# Plot and display the word cloud
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bicubic')
plt.axis('off')
plt.show()

# %%
resume_data['Category'].value_counts().sort_index().plot(kind='bar', figsize=(12, 6) )
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn-dark-palette')
plt.figure(figsize=(15,7))
plt.title("The distinct categories of resumes")
plt.xticks(rotation=90)
sns.countplot(y="Category", data=resume_data,color=None)
plt.show()
# Out:
# <ipython-input-188-0239becacaba>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-dark-palette')
